# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('../data/UNSW_2018_IoT_Botnet_Full5pc_2.csv')
# Out:
# C:\Users\szb20\AppData\Local\Temp\ipykernel_7828\3845012365.py:6: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/UNSW_2018_IoT_Botnet_Full5pc_2.csv')

# %%
# Keep only numeric columns safely
df_numeric = df.select_dtypes(include=['int64', 'float64'])

print(df_numeric.shape)
df_numeric.head()
# Out:
# (1000000, 37)
#    pkSeqID         stime  flgs_number  proto_number  pkts  bytes  \
# 0  1000001  1.528085e+09            1             3     8    480
# 1  1000002  1.528085e+09            1             3     8    480
# 2  1000003  1.528085e+09            1             3     8    480
# 3  1000004  1.528085e+09            1             3     8    480
# 4  1000005  1.528085e+09            1             3     8    480
#
#    state_number         ltime     seq        dur  ...  TnP_Per_Dport  \
# 0             4  1.528085e+09  120567  25.001644  ...            800
# 1             4  1.528085e+09  120568  25.001644  ...            800
# 2             4  1.528085e+09  120569  25.001644  ...            800
# 3             4  1.528085e+09  120570  25.001644  ...            800
# 4             4  1.528085e+09  120571  25.001644  ...            800
#
#    AR_P_Proto_P_SrcIP  AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  \
# 0            0.319943            0.319943                100
# 1            0.319943            0.319943                100
# 2            0.319943            0.319943                100
# 3            0.319943            0.319943                100
# 4            0.319943            0.319943                100
#
#    N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                100            0.319979            0.319943
# 1                100            0.319979            0.319943
# 2                100            0.319979            0.319943
# 3                100            0.319979            0.319943
# 4                100            0.319979            0.319943
#
#    Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  attack
# 0                               800                              800       1
# 1                               800                              800       1
# 2                               800                              800       1
# 3                               800                              800       1
# 4                               800                              800       1
#
# [5 rows x 37 columns]

# %%
corr_matrix = df_numeric.corr(method='pearson')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 14))
sns.heatmap(
    corr_matrix,
    cmap='coolwarm',
    linewidths=0.5
)
plt.title('Feature Correlation Heatmap (Pearson)')
plt.show()
